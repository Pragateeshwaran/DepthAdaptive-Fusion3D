# %%
from data_loader import get_LiDAR, get_radar, get_images, get_labels, get_calib
from trail import MultiModalDetectionNetwork, voxelize_lidar_proper, voxelize_radar_proper
from rpn_refinement import parse_label_line
import spconv.pytorch as spconv
from PIL import Image
import torch 
import os
checkpoint_path = r"F:\Work\DeepLearning\Research\checkpoint_epoch_20.pth"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")

# Load model
print(f"\n📦 Loading checkpoint: {checkpoint_path}")
if not os.path.exists(checkpoint_path):
    print(f"❌ Checkpoint not found: {checkpoint_path}")

model = MultiModalDetectionNetwork(lidar_dim=128, radar_dim=128, image_dim=128).to(device)
# Out:
# 🔧 ROOT CAUSE FIX: Forcing spconv to use native algorithm...
# Device: cuda
#
# 📦 Loading checkpoint: F:\Work\DeepLearning\Research\checkpoint_epoch_20.pth
# ⚙️  ProposalGenerator: score_thresh=0.001 (DEBUG - raise after training works)
# ⚙️  RPN Loss FIXED with VERY LOW thresholds:
#    Positive IoU threshold: 0.05 (to match IoU=0.0865)
#    Negative IoU threshold: 0.01
#    This will give you ~28 positive matches!
# ✓ TwoStageDetector FIXED:
#    Anchors per location: 12 (3 sizes × 4 rotations)
#    Positive IoU threshold: 0.05 (VERY LOW to get matches)
#    Negative IoU threshold: 0.01
